# %% [markdown]
# # Learning objectives
#
# 1. Plot FBtr0331261 abundance over time
#     - Load data (with index)
#     - Subset transcript (by rowname)
#     - Plot values (and index names)

# %% [markdown]
# # Reminders
#
# 1. Information
#     - `type()` to check the class of your object
#     - `.shape` to check the dimensions
#
# 1. Retrieve
#     - `.index` to retrieve names
#     - `.values` to retrieve values
# 1. Subset
#     - `.loc[]` to subset by index name
#     - `.iloc[]` to subset by integer position

# %% [markdown]
# # Load packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Load fpkms.csv

# %%
df_fpkms = pd.read_csv( "../../qbb2021/data/fpkms.csv" )
df_fpkms
# Out:
#             t_name gene_name    male_10    male_11    male_12    male_13  \
# 0      FBtr0114258   CR41571   0.000000   0.000000   0.000000   0.000000
# 1      FBtr0346770   CG45784   0.000000   0.000000   0.000000   0.000000
# 2      FBtr0302440   CR12798   0.000000   0.000000   0.000000   0.000000
# 3      FBtr0302347   CR40182  23.712564  11.967821  20.767498  13.566818
# 4      FBtr0346769   CG45783   0.000000   0.000000   0.000000   0.000000
# ...            ...       ...        ...        ...        ...        ...
# 34713  FBtr0114187   CR40502   0.000000   0.000000   0.000000   0.000000
# 34714  FBtr0304147   CR40719   0.000000   0.000000   0.000000   0.000000
# 34715  FBtr0114216   CR40679   2.011199   0.000000   7.994137   2.064200
# 34716  FBtr0114222   CR40743   0.000000   0.000000   0.000000   0.000000
# 34717  FBtr0114283   CR41619   0.000000   0.000000   0.000000   0.000000
#
#         male_14A   male_14B   male_14C   male_14D  female_10  female_11  \
# ...

# %%
# df_fpkms.loc["FBtr0331261",:]

# KeyError: 'FBtr0331261'

# %% [markdown]
# # Load fpkms.csv -- Try 2

# %%
df_fpkms = pd.read_csv( "../../qbb2021/data/fpkms.csv", index_col="t_name" )
df_fpkms
# Out:
#             gene_name    male_10    male_11    male_12    male_13   male_14A  \
# t_name
# FBtr0114258   CR41571   0.000000   0.000000   0.000000   0.000000   0.000000
# FBtr0346770   CG45784   0.000000   0.000000   0.000000   0.000000   0.000000
# FBtr0302440   CR12798   0.000000   0.000000   0.000000   0.000000   0.000000
# FBtr0302347   CR40182  23.712564  11.967821  20.767498  13.566818  18.802116
# FBtr0346769   CG45783   0.000000   0.000000   0.000000   0.000000   0.000000
# ...               ...        ...        ...        ...        ...        ...
# FBtr0114187   CR40502   0.000000   0.000000   0.000000   0.000000   0.000000
# FBtr0304147   CR40719   0.000000   0.000000   0.000000   0.000000   0.000000
# FBtr0114216   CR40679   2.011199   0.000000   7.994137   2.064200   3.141665
# FBtr0114222   CR40743   0.000000   0.000000   0.000000   0.000000   0.000000
# FBtr0114283   CR41619   0.000000   0.000000   0.000000   0.000000   0.000000
#
# ...

# %%
type( df_fpkms )
# Out:
# pandas.core.frame.DataFrame

# %%
df_fpkms.shape
# Out:
# (34718, 17)

# %% [markdown]
# # Subset transcript

# %%
goi = "FBtr0331261"

# %%
df_sxl = df_fpkms.loc[goi,:]
df_sxl
# Out:
# gene_name            Sxl
# male_10              0.0
# male_11              0.0
# male_12              0.0
# male_13              0.0
# male_14A             0.0
# male_14B             0.0
# male_14C             0.0
# male_14D        2.117317
# female_10            0.0
# female_11            0.0
# female_12            0.0
# female_13            0.0
# female_14A     46.033894
# female_14B     30.605591
# female_14C     38.956379
# female_14D    124.908493
# Name: FBtr0331261, dtype: object

# %%
type( df_sxl )
# Out:
# pandas.core.series.Series

# %%
df_sxl.shape
# Out:
# (17,)

# %% [markdown]
# # Plot time course

# %%
y = df_sxl
y
# Out:
# gene_name            Sxl
# male_10              0.0
# male_11              0.0
# male_12              0.0
# male_13              0.0
# male_14A             0.0
# male_14B             0.0
# male_14C             0.0
# male_14D        2.117317
# female_10            0.0
# female_11            0.0
# female_12            0.0
# female_13            0.0
# female_14A     46.033894
# female_14B     30.605591
# female_14C     38.956379
# female_14D    124.908493
# Name: FBtr0331261, dtype: object

# %%
x = df_sxl.index
x
# Out:
# Index(['gene_name', 'male_10', 'male_11', 'male_12', 'male_13', 'male_14A',
#        'male_14B', 'male_14C', 'male_14D', 'female_10', 'female_11',
#        'female_12', 'female_13', 'female_14A', 'female_14B', 'female_14C',
#        'female_14D'],
#       dtype='object')

# %%
# plt, ax = plt.subplots()
# ax.plot( x, y )
# plt.show()
# 
# TypeError: 'value' must be an instance of str or bytes, not a numpy.float64

# %% [markdown]
# # Plot time course -- Try 2

# %%
y = df_sxl.iloc[1:]
y
# Out:
# male_10              0.0
# male_11              0.0
# male_12              0.0
# male_13              0.0
# male_14A             0.0
# male_14B             0.0
# male_14C             0.0
# male_14D        2.117317
# female_10            0.0
# female_11            0.0
# female_12            0.0
# female_13            0.0
# female_14A     46.033894
# female_14B     30.605591
# female_14C     38.956379
# female_14D    124.908493
# Name: FBtr0331261, dtype: object

# %%
x = y.index

# %%
fig, ax = plt.subplots()
ax.plot( x, y )
plt.show()
